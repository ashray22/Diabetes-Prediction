# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the Dataset
df = pd.read_csv('D:\Jupyter Notebook\Datasets\diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df1 = df.hist(figsize = (20,20))

# %%
df['Pregnancies'].describe()
# Out:
# count    768.000000
# mean       3.845052
# std        3.369578
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       17.000000
# Name: Pregnancies, dtype: float64

# %%
sns.set(style='dark',)
plot = sns.distplot(df,color='purple')
    
plt.show()

# %%
sns.set(style='dark',)
plot = sns.distplot(df['Pregnancies'],color='purple')
    
plt.show()

# %%
df['Glucose'].describe()
# Out:
# count    768.000000
# mean     120.894531
# std       31.972618
# min        0.000000
# 25%       99.000000
# 50%      117.000000
# 75%      140.250000
# max      199.000000
# Name: Glucose, dtype: float64

# %%
sns.set(style='dark',)
plot = sns.distplot(df['Glucose'],color='green')
    
plt.show()

# %%
 df['Glucose'].mean()
# Out:
# 120.89453125

# %%
 df['Glucose'] = df['Glucose'].replace(0,120.89453125 )

# %%
df['BloodPressure'].describe()
# Out:
# count    768.000000
# mean      69.105469
# std       19.355807
# min        0.000000
# 25%       62.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %%
sns.set(style='dark',)
plot = sns.distplot(df['BloodPressure'],color='purple')
    
plt.show()

# %%
df['SkinThickness'].describe()
# Out:
# count    768.000000
# mean      20.536458
# std       15.952218
# min        0.000000
# 25%        0.000000
# 50%       23.000000
# 75%       32.000000
# max       99.000000
# Name: SkinThickness, dtype: float64

# %%
sns.set(style='dark',)
plot = sns.distplot(df['SkinThickness'],color='blue')
    
plt.show()

# %%
df['BMI'].describe()
# Out:
# count    768.000000
# mean      31.992578
# std        7.884160
# min        0.000000
# 25%       27.300000
# 50%       32.000000
# 75%       36.600000
# max       67.100000
# Name: BMI, dtype: float64

# %%
sns.set(style='dark',)
plot = sns.distplot(df['BMI'],color='purple')
    
plt.show()

# %%
df['Insulin'].describe()
# Out:
# count    768.000000
# mean      79.799479
# std      115.244002
# min        0.000000
# 25%        0.000000
# 50%       30.500000
# 75%      127.250000
# max      846.000000
# Name: Insulin, dtype: float64

# %%
sns.set(style='dark',)
plot = sns.distplot(df['Insulin'],color='purple')
    
plt.show()

# %%
df['DiabetesPedigreeFunction'].describe()
# Out:
# count    768.000000
# mean       0.471876
# std        0.331329
# min        0.078000
# 25%        0.243750
# 50%        0.372500
# 75%        0.626250
# max        2.420000
# Name: DiabetesPedigreeFunction, dtype: float64

# %%
df['Age'].describe()
# Out:
# count    768.000000
# mean      33.240885
# std       11.760232
# min       21.000000
# 25%       24.000000
# 50%       29.000000
# 75%       41.000000
# max       81.000000
# Name: Age, dtype: float64

# %%
col = ['Glucose','BloodPressure','BMI','SkinThickness']

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0             72             35        0  33.6
# 1              1     85.0             66             29        0  26.6
# 2              8    183.0             64              0        0  23.3
# 3              1     89.0             66             23       94  28.1
# 4              0    137.0             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0             76             48      180  32.9
# 764            2    122.0             70             27        0  36.8
# 765            5    121.0             72             23      112  26.2
# 766            1    126.0             60              0        0  30.1
# 767            1     93.0             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
for i in col:
    df[i].replace(0,df[i].mean(),inplace=True)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0      35.000000        0  33.6
# 1              1     85.0           66.0      29.000000        0  26.6
# 2              8    183.0           64.0      20.536458        0  23.3
# 3              1     89.0           66.0      23.000000       94  28.1
# 4              0    137.0           40.0      35.000000      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0      48.000000      180  32.9
# 764            2    122.0           70.0      27.000000        0  36.8
# 765            5    121.0           72.0      23.000000      112  26.2
# 766            1    126.0           60.0      20.536458        0  30.1
# 767            1     93.0           70.0      31.000000        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df['Glucose'].describe()
# Out:
# count    768.000000
# mean     121.681605
# std       30.436016
# min       44.000000
# 25%       99.750000
# 50%      117.000000
# 75%      140.250000
# max      199.000000
# Name: Glucose, dtype: float64

# %%
sns.set(style='dark',)
plot = sns.distplot(df['Glucose'],color='green')
    
plt.show()

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0      35.000000        0  33.6
# 1              1     85.0           66.0      29.000000        0  26.6
# 2              8    183.0           64.0      20.536458        0  23.3
# 3              1     89.0           66.0      23.000000       94  28.1
# 4              0    137.0           40.0      35.000000      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0      48.000000      180  32.9
# 764            2    122.0           70.0      27.000000        0  36.8
# 765            5    121.0           72.0      23.000000      112  26.2
# 766            1    126.0           60.0      20.536458        0  30.1
# 767            1     93.0           70.0      31.000000        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df['Insulin'].replace(0,df['Insulin'].median(),inplace=True)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0      35.000000     30.5  33.6
# 1              1     85.0           66.0      29.000000     30.5  26.6
# 2              8    183.0           64.0      20.536458     30.5  23.3
# 3              1     89.0           66.0      23.000000     94.0  28.1
# 4              0    137.0           40.0      35.000000    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0      48.000000    180.0  32.9
# 764            2    122.0           70.0      27.000000     30.5  36.8
# 765            5    121.0           72.0      23.000000    112.0  26.2
# 766            1    126.0           60.0      20.536458     30.5  30.1
# 767            1     93.0           70.0      31.000000     30.5  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
sns.set(style='dark',)
plot = sns.distplot(df['Insulin'],color='green')
    
plt.show()

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0      35.000000     30.5  33.6
# 1              1     85.0           66.0      29.000000     30.5  26.6
# 2              8    183.0           64.0      20.536458     30.5  23.3
# 3              1     89.0           66.0      23.000000     94.0  28.1
# 4              0    137.0           40.0      35.000000    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0      48.000000    180.0  32.9
# 764            2    122.0           70.0      27.000000     30.5  36.8
# 765            5    121.0           72.0      23.000000    112.0  26.2
# 766            1    126.0           60.0      20.536458     30.5  30.1
# 767            1     93.0           70.0      31.000000     30.5  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df1 = df.hist(figsize = (20,20))

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0      35.000000     30.5  33.6
# 1              1     85.0           66.0      29.000000     30.5  26.6
# 2              8    183.0           64.0      20.536458     30.5  23.3
# 3              1     89.0           66.0      23.000000     94.0  28.1
# 4              0    137.0           40.0      35.000000    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0      48.000000    180.0  32.9
# 764            2    122.0           70.0      27.000000     30.5  36.8
# 765            5    121.0           72.0      23.000000    112.0  26.2
# 766            1    126.0           60.0      20.536458     30.5  30.1
# 767            1     93.0           70.0      31.000000     30.5  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
X = df.drop(['Outcome'], axis = 1)

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0      35.000000     30.5  33.6
# 1              1     85.0           66.0      29.000000     30.5  26.6
# 2              8    183.0           64.0      20.536458     30.5  23.3
# 3              1     89.0           66.0      23.000000     94.0  28.1
# 4              0    137.0           40.0      35.000000    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0      48.000000    180.0  32.9
# 764            2    122.0           70.0      27.000000     30.5  36.8
# 765            5    121.0           72.0      23.000000    112.0  26.2
# 766            1    126.0           60.0      20.536458     30.5  30.1
# 767            1     93.0           70.0      31.000000     30.5  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
# STANDARDIZING THE DATA
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit_transform(X)
# Out:
# array([[ 0.63994726,  0.86527574, -0.0210444 , ...,  0.16725546,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.20598931, -0.51658286, ..., -0.85153454,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  2.01597855, -0.68176235, ..., -1.33182125,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 , -0.02240928, -0.0210444 , ..., -0.90975111,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.14197684, -1.01212132, ..., -0.34213954,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.94297153, -0.18622389, ..., -0.29847711,
#         -0.47378505, -0.87137393]])

# %%
X = sc.fit_transform(X)

# %%
y = pd.DataFrame(df['Outcome'])

# %%
y
# Out:
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
# ..       ...
# 763        0
# 764        0
# 765        0
# 766        1
# 767        0
#
# [768 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=100)

# %%
X_train.shape
# Out:
# (514, 8)

# %%
y_test.shape
# Out:
# (254, 1)

# %%
# Model Training and HyperParameter Tuning ( LOGISTIC REGRESSION)

from sklearn.linear_model import LogisticRegression
from sklearn import metrics
LR = LogisticRegression()
from sklearn.metrics import plot_confusion_matrix,classification_report,accuracy_score
param_grid = [    
    {'penalty' : ['l2', 'elasticnet'],
    'C' : np.logspace(-4, 4, 20),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter' : [10, 100, 500,1000]
    }
]
from sklearn.model_selection import GridSearchCV
GSCV_lr = GridSearchCV(LR, param_grid = param_grid, cv = 4, verbose=True)
best_GSCV_lr = GSCV_lr.fit(X,y)
p1 = best_GSCV_lr.predict(X_test)
c1 = best_GSCV_lr.score(X,y)
a1= "{:.2f}%".format(100*c1)
best_GSCV_lr.best_estimator_
print ('Accuracy of LOGISTIC REGRESSION :', a1 )
plot_confusion_matrix(best_GSCV_lr,X_test,y_test,cmap='Blues')
plt.grid(False)
print("Classification report for Logitic Regression:\n ",classification_report(y_test,p1))
# Out:
# Fitting 4 folds for each of 800 candidates, totalling 3200 fits
# Accuracy of LOGISTIC REGRESSION : 78.12%
# Classification report for Logitic Regression:
#                 precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81       163
#            1       0.68      0.56      0.61        91
#
#     accuracy                           0.75       254
#    macro avg       0.73      0.71      0.71       254
# weighted avg       0.74      0.75      0.74       254

# %%
best_GSCV_lr.best_params_
# Out:
# {'C': 0.03359818286283781,
#  'max_iter': 10,
#  'penalty': 'l2',
#  'solver': 'liblinear'}

# %%
# Model Training(RANDOM FOREST CLASSIFIER)
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
clf = rf.fit(X_train,y_train)
y_pred_rf = clf.predict(X_test)
plot_confusion_matrix(clf,X_test,y_test,cmap='Blues')
plt.grid(False)
print("Classification report:\n ",classification_report(y_test,y_pred_rf))
print('Accuracy : ',metrics.accuracy_score(y_test,y_pred_rf))
# Out:
# Classification report:
#                 precision    recall  f1-score   support
#
#            0       0.77      0.80      0.78       163
#            1       0.61      0.56      0.59        91
#
#     accuracy                           0.72       254
#    macro avg       0.69      0.68      0.69       254
# weighted avg       0.71      0.72      0.71       254
#
# Accuracy :  0.7165354330708661

# %%
# Model Training And HyperParameter Tuning (RANDOM FOREST CLASSIFIER)
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}
GSCV_rf = GridSearchCV(rf,param_grid = param_grid, cv = 4, verbose = 2)

# %%
best_GSCV_rf = GSCV_rf.fit(X,y)
# Out:
# Fitting 4 folds for each of 288 candidates, totalling 1152 fits
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   0.1s
# [CV] END bootstrap=True, max_depth=80, max_features=2, min_samples_leaf=3, min_samples_split=8, n_estimators=200; total time=   0.1s
# ...

# %%
p2 = best_GSCV_rf.predict(X_test)
c2 = best_GSCV_rf.score(X,y)
a2= "{:.2f}%".format(100*c2)
best_GSCV_rf.best_estimator_
print ('Accuracy of Random Forest :', a2 )
plot_confusion_matrix(best_GSCV_rf,X_test,y_test,cmap='Blues')
plt.grid(False)
print("Classification report for Random Forest:\n ",classification_report(y_test,p2))
# Out:
# Accuracy of Random Forest : 91.28%
# Classification report for Random Forest:
#                 precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90       163
#            1       0.85      0.79      0.82        91
#
#     accuracy                           0.87       254
#    macro avg       0.87      0.86      0.86       254
# weighted avg       0.87      0.87      0.87       254

# %%
best_GSCV_rf.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 80,
#  'max_features': 3,
#  'min_samples_leaf': 5,
#  'min_samples_split': 10,
#  'n_estimators': 200}

# %%
# Model Training And HyperParameter Tuning (DECISION TREE CLASSIFIER)
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
param_grids = {
    'max_depth': [2, 3, 5, 10, 20,35,60],
    'min_samples_leaf': [5, 10, 20, 50, 100,200],
    'criterion': ["gini", "entropy"]
}
GSCV_dt = GridSearchCV(estimator=dt, param_grid=param_grids, cv=4, n_jobs=-1, verbose=1)

# %%
best_GSCV_dt = GSCV_dt.fit(X,y)
# Out:
# Fitting 4 folds for each of 84 candidates, totalling 336 fits

# %%
p3 = best_GSCV_dt.predict(X_test)
c3 = best_GSCV_dt.score(X,y)
a3= "{:.2f}%".format(100*c3)
best_GSCV_dt.best_estimator_
print ('Accuracy of Decision tree :', a3 )
plot_confusion_matrix(best_GSCV_dt,X_test,y_test,cmap='Blues')
plt.grid(False)
print("Classification report for Decision Tree Classifier :\n ",classification_report(y_test,p3))

# %%
best_GSCV_dt.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 20}

# %%
# !pip install vecstack

# %%
# models = [
#     LogisticRegression(C = 0.03359818286283781, max_iter = 10,penalty= 'l2',solver = 'liblinear'),
#     RandomForestClassifier(bootstrap=True,max_depth= 80,max_features = 3,min_samples_leaf = 5,min_samples_split = 10,n_estimators = 200),
#     DecisionTreeClassifier(criterion = 'gini', max_depth = 5, min_samples_leaf = 20)
    
# ]
models = [best_GSCV_lr,best_GSCV_dt,best_GSCV_rf]

# %%
from vecstack import stacking
S_train, S_test = stacking(models, X_train,y_train,X_test,regression=False,
                          mode='oof_pred_bag',needs_proba=False,save_dir=None,
                          metric=accuracy_score,n_folds=4,stratified=True,random_state=0,verbose=2,shuffle=True)
# Out:
# task:         [classification]
# n_classes:    [2]
# metric:       [accuracy_score]
# mode:         [oof_pred_bag]
# n_models:     [3]
#
# model  0:     [GridSearchCV]
# Fitting 4 folds for each of 800 candidates, totalling 3200 fits
#     fold  0:  [0.72093023]
# Fitting 4 folds for each of 800 candidates, totalling 3200 fits
#     fold  1:  [0.76744186]
# Fitting 4 folds for each of 800 candidates, totalling 3200 fits
#     fold  2:  [0.78906250]
# Fitting 4 folds for each of 800 candidates, totalling 3200 fits
#     fold  3:  [0.80468750]
#     ----
#     MEAN:     [0.77053052] + [0.03154307]
#     FULL:     [0.77042802]
#
# model  1:     [GridSearchCV]
# Fitting 4 folds for each of 84 candidates, totalling 336 fits
#     fold  0:  [0.72868217]
# Fitting 4 folds for each of 84 candidates, totalling 336 fits
#     fold  1:  [0.79844961]
# Fitting 4 folds for each of 84 candidates, totalling 336 fits
#     fold  2:  [0.63281250]
# ...

# %%
model = LogisticRegression()
model = model.fit(X_train,y_train)

# %%
y_pred = model.predict(S_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [83], in <cell line: 1>()
# ----> 1 y_pred = model.predict(S_test)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:425, in LinearClassifierMixin.predict(self, X)
#     411 def predict(self, X):
#     412     """
#     413     Predict class labels for samples in X.
#     414
#    (...)
#     423         Vector containing the class labels for each sample.
#     424     """
# --> 425     scores = self.decision_function(X)
#     426     if len(scores.shape) == 1:
#     427         indices = (scores > 0).astype(int)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:407, in LinearClassifierMixin.decision_function(self, X)
#     387 """
#     388 Predict confidence scores for samples.
#     389
#    (...)
#     403     this class would be predicted.
#     404 """
# ...
